# %%
import pandas as pd

# %%
survey = pd.read_csv(r"D:\New folder\survey_results_public.csv")

# %%
survey
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
survey.dtypes
# Out:
# ResponseId                        int64
# MainBranch                       object
# Employment                       object
# Country                          object
# US_State                         object
# UK_Country                       object
# EdLevel                          object
# Age1stCode                       object
# LearnCode                        object
# YearsCode                        object
# YearsCodePro                     object
# DevType                          object
# OrgSize                          object
# Currency                         object
# CompTotal                       float64
# CompFreq                         object
# LanguageHaveWorkedWith           object
# LanguageWantToWorkWith           object
# DatabaseHaveWorkedWith           object
# DatabaseWantToWorkWith           object
# PlatformHaveWorkedWith           object
# PlatformWantToWorkWith           object
# WebframeHaveWorkedWith           object
# ...

# %%
survey['Age1stCode']
# Out:
# 0        18 - 24 years
# 1        11 - 17 years
# 2        11 - 17 years
# 3        11 - 17 years
# 4         5 - 10 years
#              ...
# 83434    11 - 17 years
# 83435    11 - 17 years
# 83436    11 - 17 years
# 83437    11 - 17 years
# 83438    11 - 17 years
# Name: Age1stCode, Length: 83439, dtype: object

# %%
survey['Age1stCode'].isnull().values.any
# Out:
# <function ndarray.any>

# %%
survey = survey.dropna(subset=['Age1stCode'])

# %%
df1 = survey[survey['Age1stCode'].isna()]

# %%
df1
# Out:
# Empty DataFrame
# Columns: [ResponseId, MainBranch, Employment, Country, US_State, UK_Country, EdLevel, Age1stCode, LearnCode, YearsCode, YearsCodePro, DevType, OrgSize, Currency, CompTotal, CompFreq, LanguageHaveWorkedWith, LanguageWantToWorkWith, DatabaseHaveWorkedWith, DatabaseWantToWorkWith, PlatformHaveWorkedWith, PlatformWantToWorkWith, WebframeHaveWorkedWith, WebframeWantToWorkWith, MiscTechHaveWorkedWith, MiscTechWantToWorkWith, ToolsTechHaveWorkedWith, ToolsTechWantToWorkWith, NEWCollabToolsHaveWorkedWith, NEWCollabToolsWantToWorkWith, OpSys, NEWStuck, NEWSOSites, SOVisitFreq, SOAccount, SOPartFreq, SOComm, NEWOtherComms, Age, Gender, Trans, Sexuality, Ethnicity, Accessibility, MentalHealth, SurveyLength, SurveyEase, ConvertedCompYearly]
# Index: []
#
# [0 rows x 48 columns]

# %%
survey['Age1stCode'] = survey['Age1stCode'].str.replace(r'\D', '').astype(int)
# Out:
# C:\Users\sache\AppData\Local\Temp\ipykernel_50028\3954787407.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   survey['Age1stCode'] = survey['Age1stCode'].str.replace(r'\D', '').astype(int)
# C:\Users\sache\AppData\Local\Temp\ipykernel_50028\3954787407.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey['Age1stCode'] = survey['Age1stCode'].str.replace(r'\D', '').astype(int)

# %%
survey
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
survey['Age1stCode'] = pd.to_numeric(survey['Age1stCode'].astype(str).str[0:2], errors='coerce')
# Out:
# C:\Users\sache\AppData\Local\Temp\ipykernel_50028\1753384317.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey['Age1stCode'] = pd.to_numeric(survey['Age1stCode'].astype(str).str[0:2], errors='coerce')

# %%
survey
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
survey.dtypes
# Out:
# ResponseId                        int64
# MainBranch                       object
# Employment                       object
# Country                          object
# US_State                         object
# UK_Country                       object
# EdLevel                          object
# Age1stCode                        int64
# LearnCode                        object
# YearsCode                        object
# YearsCodePro                     object
# DevType                          object
# OrgSize                          object
# Currency                         object
# CompTotal                       float64
# CompFreq                         object
# LanguageHaveWorkedWith           object
# LanguageWantToWorkWith           object
# DatabaseHaveWorkedWith           object
# DatabaseWantToWorkWith           object
# PlatformHaveWorkedWith           object
# PlatformWantToWorkWith           object
# WebframeHaveWorkedWith           object
# ...

# %%
survey['YearsCode'].unique()
# Out:
# array([nan, '7', '17', '3', '4', '6', '16', '12', '15', '10', '40', '9',
#        '26', '14', '39', '20', '8', '19', '5', 'Less than 1 year', '22',
#        '2', '1', '34', '21', '13', '25', '24', '30', '31', '18', '38',
#        'More than 50 years', '27', '41', '42', '35', '23', '28', '11',
#        '37', '44', '43', '36', '33', '45', '29', '50', '46', '32', '47',
#        '49', '48'], dtype=object)

# %%
survey['YearsCode'] = survey['YearsCode'].str.replace(r'Less than 1 year', '0.5')
survey['YearsCode'] = survey['YearsCode'].str.replace(r'More than 50 years', '55')
# Out:
# C:\Users\sache\AppData\Local\Temp\ipykernel_50028\622472640.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey['YearsCode'] = survey['YearsCode'].str.replace(r'Less than 1 year', '0.5')
# C:\Users\sache\AppData\Local\Temp\ipykernel_50028\622472640.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey['YearsCode'] = survey['YearsCode'].str.replace(r'More than 50 years', '55')

# %%
survey['YearsCode'].unique()
# Out:
# array([nan, '7', '17', '3', '4', '6', '16', '12', '15', '10', '40', '9',
#        '26', '14', '39', '20', '8', '19', '5', '0.5', '22', '2', '1',
#        '34', '21', '13', '25', '24', '30', '31', '18', '38', '55', '27',
#        '41', '42', '35', '23', '28', '11', '37', '44', '43', '36', '33',
#        '45', '29', '50', '46', '32', '47', '49', '48'], dtype=object)

# %%
survey['Age'] = pd.to_numeric(survey['Age'].astype(str).str[0:2], errors='coerce')
# Out:
# C:\Users\sache\AppData\Local\Temp\ipykernel_50028\1397289309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   survey['Age'] = pd.to_numeric(survey['Age'].astype(str).str[0:2], errors='coerce')

# %%
survey
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
survey
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
survey.dtypes
# Out:
# ResponseId                        int64
# MainBranch                       object
# Employment                       object
# Country                          object
# US_State                         object
# UK_Country                       object
# EdLevel                          object
# Age1stCode                        int64
# LearnCode                        object
# YearsCode                        object
# YearsCodePro                     object
# DevType                          object
# OrgSize                          object
# Currency                         object
# CompTotal                       float64
# CompFreq                         object
# LanguageHaveWorkedWith           object
# LanguageWantToWorkWith           object
# DatabaseHaveWorkedWith           object
# DatabaseWantToWorkWith           object
# PlatformHaveWorkedWith           object
# PlatformWantToWorkWith           object
# WebframeHaveWorkedWith           object
# ...

# %%
selected_columns = [
    # Demographics
    'Country',
    'Age',
    'Gender',
    'EdLevel',
    
    # Programming experience
    
    'Age1stCode',
    'YearsCode',
    'YearsCodePro',
    
  
   
    'NEWStuck',
    # Employment
    'Employment',
    'DevType',
    
    
    
]

# %%
survey_df = survey[selected_columns].copy()

# %%
survey_df.head(10)
# Out:
#                                              Country   Age             Gender  \
# 0                                           Slovakia  25.0                Man
# 1                                        Netherlands  18.0                Man
# 2                                 Russian Federation  18.0                Man
# 3                                            Austria  35.0                Man
# 4  United Kingdom of Great Britain and Northern I...  25.0                Man
# 5                           United States of America  18.0  Prefer not to say
# 6                           United States of America   NaN  Prefer not to say
# 7                                           Malaysia  18.0              Woman
# 8                                              India  25.0                Man
# 9                                             Sweden  25.0                Man
#
#                                              EdLevel  Age1stCode YearsCode  \
# ...

# %%
survey_df['YearsCode'] = survey_df['YearsCode'].astype(float)

# %%
survey_df['YearsCodePro'].unique()
# Out:
# array([nan, '10', '4', '5', '6', '2', '30', '9', '18', '12', '21', '1',
#        '16', 'Less than 1 year', '15', '3', '35', '7', '8', '17', '14',
#        '26', '25', '20', '50', '34', '11', '24', '22', '13', '31', '23',
#        '39', '41', '27', '28', '19', '33', 'More than 50 years', '37',
#        '29', '32', '43', '40', '38', '45', '42', '46', '36', '44', '47',
#        '48', '49'], dtype=object)

# %%
survey_df['YearsCodePro'] = survey_df['YearsCodePro'].str.replace(r'Less than 1 year', '0.5')
survey_df['YearsCodePro'] = survey_df['YearsCodePro'].str.replace(r'More than 50 years', '55')

# %%
survey_df['YearsCodePro'] = survey_df['YearsCodePro'].astype(float)

# %%
survey_df.dtypes
# Out:
# Country          object
# Age             float64
# Gender           object
# EdLevel          object
# Age1stCode        int64
# YearsCode       float64
# YearsCodePro    float64
# NEWStuck         object
# Employment       object
# DevType          object
# dtype: object

# %%
survey_df.describe()
# Out:
#                 Age    Age1stCode     YearsCode  YearsCodePro
# count  76382.000000  83243.000000  81573.000000  61182.000000
# mean      27.427116     19.742765     12.359843      9.211018
# std        9.284835     14.001983      9.856888      8.259435
# min       18.000000      5.000000      0.500000      0.500000
# 25%       18.000000     11.000000      5.000000      3.000000
# 50%       25.000000     11.000000     10.000000      6.000000
# 75%       35.000000     18.000000     17.000000     13.000000
# max       65.000000     64.000000     55.000000     55.000000
